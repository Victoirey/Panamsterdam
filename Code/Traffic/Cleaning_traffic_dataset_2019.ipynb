# %%
import pandas as pd
import numpy as np

# %%
velo=pd.read_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Compteurs\2019_comptage-velo-donnees-compteurs.csv', sep=";")
velo.head()
# Out:
#   Identifiant du compteur                     Nom du compteur  \
# 0            100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 1            100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 2            100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 3            100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 4            100047539-SC  21 Boulevard Auguste Blanqui SO-NE
#
#    Identifiant du site de comptage             Nom du site de comptage  \
# 0                        100047539  21 Boulevard Auguste Blanqui SO-NE
# 1                        100047539  21 Boulevard Auguste Blanqui SO-NE
# 2                        100047539  21 Boulevard Auguste Blanqui SO-NE
# 3                        100047539  21 Boulevard Auguste Blanqui SO-NE
# 4                        100047539  21 Boulevard Auguste Blanqui SO-NE
#
#    Comptage horaire  Date et heure de comptage  \
# 0                 0  2019-01-01T07:00:00+01:00
# 1                31  2019-01-02T18:00:00+01:00
# 2                24  2019-01-03T16:00:00+01:00
# 3                 2  2019-01-04T04:00:00+01:00
# 4                 0  2019-01-04T08:00:00+01:00
#
#   Date d'installation du site de comptage  \
# 0                              2018-12-05
# 1                              2018-12-05
# 2                              2018-12-05
# 3                              2018-12-05
# 4                              2018-12-05
#
#                  Lien vers photo du site de comptage Coordonnées géographiques
# 0  https://www.eco-visio.net/Photos/100047539/157...        48.830449,2.353199
# 1  https://www.eco-visio.net/Photos/100047539/157...        48.830449,2.353199
# 2  https://www.eco-visio.net/Photos/100047539/157...        48.830449,2.353199
# 3  https://www.eco-visio.net/Photos/100047539/157...        48.830449,2.353199
# 4  https://www.eco-visio.net/Photos/100047539/157...        48.830449,2.353199

# %%
velo.columns
# Out:
# Index(['Identifiant du compteur', 'Nom du compteur',
#        'Identifiant du site de comptage', 'Nom du site de comptage',
#        'Comptage horaire', 'Date et heure de comptage',
#        'Date d'installation du site de comptage',
#        'Lien vers photo du site de comptage', 'Coordonnées géographiques'],
#       dtype='object')

# %%
velo.rename(columns={'Identifiant du compteur': 'compteur_id', 'Nom du compteur': 'compteur_name',
       'Identifiant du site de comptage': 'site_compteur_id', 'Nom du site de comptage': 'compteur_name2',
       'Comptage horaire': 'comptage_horaire', 'Date et heure de comptage': 'date_heure_comptage',
       "Date d'installation du site de comptage": 'date_instal',
       'Coordonnées géographiques': 'coord_gps'}, inplace=True)

# %%
velo.drop(['Lien vers photo du site de comptage'], axis=1, inplace=True)
velo
# Out:
#                 compteur_id                       compteur_name  \
# 0              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 1              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 2              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 3              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 4              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# ...                     ...                                 ...
# 436724  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436725  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436726  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436727  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436728  100056336-105056336       27 Quai de la Tournelle SE-NO
#
#         site_compteur_id                      compteur_name2  \
# 0              100047539  21 Boulevard Auguste Blanqui SO-NE
# 1              100047539  21 Boulevard Auguste Blanqui SO-NE
# 2              100047539  21 Boulevard Auguste Blanqui SO-NE
# 3              100047539  21 Boulevard Auguste Blanqui SO-NE
# 4              100047539  21 Boulevard Auguste Blanqui SO-NE
# ...                  ...                                 ...
# 436724         100056336             27 Quai de la Tournelle
# 436725         100056336             27 Quai de la Tournelle
# 436726         100056336             27 Quai de la Tournelle
# 436727         100056336             27 Quai de la Tournelle
# 436728         100056336             27 Quai de la Tournelle
#
#         comptage_horaire        date_heure_comptage date_instal  \
# 0                      0  2019-01-01T07:00:00+01:00  2018-12-05
# 1                     31  2019-01-02T18:00:00+01:00  2018-12-05
# 2                     24  2019-01-03T16:00:00+01:00  2018-12-05
# 3                      2  2019-01-04T04:00:00+01:00  2018-12-05
# 4                      0  2019-01-04T08:00:00+01:00  2018-12-05
# ...                  ...                        ...         ...
# 436724                85  2019-12-27T11:00:00+01:00  2019-11-14
# 436725                96  2019-12-27T19:00:00+01:00  2019-11-14
# 436726               114  2019-12-29T14:00:00+01:00  2019-11-14
# 436727                43  2019-12-30T06:00:00+01:00  2019-11-14
# 436728                91  2019-12-30T15:00:00+01:00  2019-11-14
#
#                  coord_gps
# 0       48.830449,2.353199
# 1       48.830449,2.353199
# 2       48.830449,2.353199
# 3       48.830449,2.353199
# 4       48.830449,2.353199
# ...                    ...
# 436724    48.85013,2.35423
# 436725    48.85013,2.35423
# 436726    48.85013,2.35423
# 436727    48.85013,2.35423
# 436728    48.85013,2.35423
#
# [436729 rows x 8 columns]

# %%
velo.dtypes
# Out:
# compteur_id            object
# compteur_name          object
# site_compteur_id        int64
# compteur_name2         object
# comptage_horaire        int64
# date_heure_comptage    object
# date_instal            object
# coord_gps              object
# dtype: object

# %%
velo.isna().sum()
# Out:
# compteur_id            0
# compteur_name          0
# site_compteur_id       0
# compteur_name2         0
# comptage_horaire       0
# date_heure_comptage    0
# date_instal            0
# coord_gps              0
# dtype: int64

# %%
from datetime import datetime
velo['jour_comptage']=pd.to_datetime(velo['date_heure_comptage'], format='%Y/%m/%d')

# %%
velo['jour_comptage'].value_counts()
# Out:
# 2019-03-31 03:00:00+02:00    84
# 2019-12-13 00:00:00+01:00    81
# 2019-12-21 16:00:00+01:00    81
# 2019-12-19 10:00:00+01:00    81
# 2019-12-17 23:00:00+01:00    81
#                              ..
# 2019-04-05 08:00:00+02:00    45
# 2019-04-04 10:00:00+02:00    45
# 2019-04-04 04:00:00+02:00    45
# 2019-04-03 14:00:00+02:00    45
# 2019-04-15 02:00:00+02:00    45
# Name: jour_comptage, Length: 8736, dtype: int64

# %%
velo['date_comptage'] = velo['date_heure_comptage'].str[:10]
velo.head()
# Out:
#     compteur_id                       compteur_name  site_compteur_id  \
# 0  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 1  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 2  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 3  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 4  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
#
#                        compteur_name2  comptage_horaire  \
# 0  21 Boulevard Auguste Blanqui SO-NE                 0
# 1  21 Boulevard Auguste Blanqui SO-NE                31
# 2  21 Boulevard Auguste Blanqui SO-NE                24
# 3  21 Boulevard Auguste Blanqui SO-NE                 2
# 4  21 Boulevard Auguste Blanqui SO-NE                 0
#
#          date_heure_comptage date_instal           coord_gps  \
# 0  2019-01-01T07:00:00+01:00  2018-12-05  48.830449,2.353199
# 1  2019-01-02T18:00:00+01:00  2018-12-05  48.830449,2.353199
# 2  2019-01-03T16:00:00+01:00  2018-12-05  48.830449,2.353199
# 3  2019-01-04T04:00:00+01:00  2018-12-05  48.830449,2.353199
# 4  2019-01-04T08:00:00+01:00  2018-12-05  48.830449,2.353199
#
#                jour_comptage date_comptage
# 0  2019-01-01 07:00:00+01:00    2019-01-01
# 1  2019-01-02 18:00:00+01:00    2019-01-02
# 2  2019-01-03 16:00:00+01:00    2019-01-03
# 3  2019-01-04 04:00:00+01:00    2019-01-04
# 4  2019-01-04 08:00:00+01:00    2019-01-04

# %%
velo['date_comptage']=pd.to_datetime(velo['date_comptage'], format='%Y/%m/%d')
velo.dtypes
# Out:
# compteur_id                    object
# compteur_name                  object
# site_compteur_id                int64
# compteur_name2                 object
# comptage_horaire                int64
# date_heure_comptage            object
# date_instal                    object
# coord_gps                      object
# jour_comptage                  object
# date_comptage          datetime64[ns]
# dtype: object

# %%
velo['heure_comptage'] = velo['date_heure_comptage'].str[11:]

# %%
velo['heure_comptage']=velo['heure_comptage'].str[:2]
velo.head()
# Out:
#     compteur_id                       compteur_name  site_compteur_id  \
# 0  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 1  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 2  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 3  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 4  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
#
#                        compteur_name2  comptage_horaire  \
# 0  21 Boulevard Auguste Blanqui SO-NE                 0
# 1  21 Boulevard Auguste Blanqui SO-NE                31
# 2  21 Boulevard Auguste Blanqui SO-NE                24
# 3  21 Boulevard Auguste Blanqui SO-NE                 2
# 4  21 Boulevard Auguste Blanqui SO-NE                 0
#
#          date_heure_comptage date_instal           coord_gps  \
# 0  2019-01-01T07:00:00+01:00  2018-12-05  48.830449,2.353199
# 1  2019-01-02T18:00:00+01:00  2018-12-05  48.830449,2.353199
# 2  2019-01-03T16:00:00+01:00  2018-12-05  48.830449,2.353199
# 3  2019-01-04T04:00:00+01:00  2018-12-05  48.830449,2.353199
# 4  2019-01-04T08:00:00+01:00  2018-12-05  48.830449,2.353199
#
#                jour_comptage date_comptage heure_comptage
# 0  2019-01-01 07:00:00+01:00    2019-01-01             07
# 1  2019-01-02 18:00:00+01:00    2019-01-02             18
# 2  2019-01-03 16:00:00+01:00    2019-01-03             16
# 3  2019-01-04 04:00:00+01:00    2019-01-04             04
# 4  2019-01-04 08:00:00+01:00    2019-01-04             08

# %%
velo['heure_comptage']=velo['heure_comptage'].astype(int)
velo.dtypes
# Out:
# compteur_id                    object
# compteur_name                  object
# site_compteur_id                int64
# compteur_name2                 object
# comptage_horaire                int64
# date_heure_comptage            object
# date_instal                    object
# coord_gps                      object
# jour_comptage                  object
# date_comptage          datetime64[ns]
# heure_comptage                  int32
# dtype: object

# %%
velo[['latitude', 'longitude']] = velo['coord_gps'].str.split(',', expand=True)
velo
# Out:
#                 compteur_id                       compteur_name  \
# 0              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 1              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 2              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 3              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# 4              100047539-SC  21 Boulevard Auguste Blanqui SO-NE
# ...                     ...                                 ...
# 436724  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436725  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436726  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436727  100056336-105056336       27 Quai de la Tournelle SE-NO
# 436728  100056336-105056336       27 Quai de la Tournelle SE-NO
#
#         site_compteur_id                      compteur_name2  \
# 0              100047539  21 Boulevard Auguste Blanqui SO-NE
# 1              100047539  21 Boulevard Auguste Blanqui SO-NE
# 2              100047539  21 Boulevard Auguste Blanqui SO-NE
# 3              100047539  21 Boulevard Auguste Blanqui SO-NE
# 4              100047539  21 Boulevard Auguste Blanqui SO-NE
# ...                  ...                                 ...
# 436724         100056336             27 Quai de la Tournelle
# 436725         100056336             27 Quai de la Tournelle
# 436726         100056336             27 Quai de la Tournelle
# 436727         100056336             27 Quai de la Tournelle
# 436728         100056336             27 Quai de la Tournelle
#
#         comptage_horaire        date_heure_comptage date_instal  \
# 0                      0  2019-01-01T07:00:00+01:00  2018-12-05
# 1                     31  2019-01-02T18:00:00+01:00  2018-12-05
# 2                     24  2019-01-03T16:00:00+01:00  2018-12-05
# 3                      2  2019-01-04T04:00:00+01:00  2018-12-05
# 4                      0  2019-01-04T08:00:00+01:00  2018-12-05
# ...                  ...                        ...         ...
# 436724                85  2019-12-27T11:00:00+01:00  2019-11-14
# 436725                96  2019-12-27T19:00:00+01:00  2019-11-14
# 436726               114  2019-12-29T14:00:00+01:00  2019-11-14
# 436727                43  2019-12-30T06:00:00+01:00  2019-11-14
# 436728                91  2019-12-30T15:00:00+01:00  2019-11-14
#
#                  coord_gps              jour_comptage date_comptage  \
# 0       48.830449,2.353199  2019-01-01 07:00:00+01:00    2019-01-01
# 1       48.830449,2.353199  2019-01-02 18:00:00+01:00    2019-01-02
# 2       48.830449,2.353199  2019-01-03 16:00:00+01:00    2019-01-03
# 3       48.830449,2.353199  2019-01-04 04:00:00+01:00    2019-01-04
# 4       48.830449,2.353199  2019-01-04 08:00:00+01:00    2019-01-04
# ...                    ...                        ...           ...
# 436724    48.85013,2.35423  2019-12-27 11:00:00+01:00    2019-12-27
# 436725    48.85013,2.35423  2019-12-27 19:00:00+01:00    2019-12-27
# 436726    48.85013,2.35423  2019-12-29 14:00:00+01:00    2019-12-29
# 436727    48.85013,2.35423  2019-12-30 06:00:00+01:00    2019-12-30
# 436728    48.85013,2.35423  2019-12-30 15:00:00+01:00    2019-12-30
#
#         heure_comptage   latitude longitude
# 0                    7  48.830449  2.353199
# 1                   18  48.830449  2.353199
# 2                   16  48.830449  2.353199
# 3                    4  48.830449  2.353199
# 4                    8  48.830449  2.353199
# ...                ...        ...       ...
# 436724              11   48.85013   2.35423
# 436725              19   48.85013   2.35423
# 436726              14   48.85013   2.35423
# 436727               6   48.85013   2.35423
# 436728              15   48.85013   2.35423
#
# [436729 rows x 13 columns]

# %%
velo.drop(['compteur_name2'], axis=1, inplace=True)

# %%
velo.drop(['jour_comptage', 'coord_gps'], axis=1, inplace=True)
velo.head()
# Out:
#     compteur_id                       compteur_name  site_compteur_id  \
# 0  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 1  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 2  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 3  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
# 4  100047539-SC  21 Boulevard Auguste Blanqui SO-NE         100047539
#
#    comptage_horaire        date_heure_comptage date_instal date_comptage  \
# 0                 0  2019-01-01T07:00:00+01:00  2018-12-05    2019-01-01
# 1                31  2019-01-02T18:00:00+01:00  2018-12-05    2019-01-02
# 2                24  2019-01-03T16:00:00+01:00  2018-12-05    2019-01-03
# 3                 2  2019-01-04T04:00:00+01:00  2018-12-05    2019-01-04
# 4                 0  2019-01-04T08:00:00+01:00  2018-12-05    2019-01-04
#
#    heure_comptage   latitude longitude
# 0               7  48.830449  2.353199
# 1              18  48.830449  2.353199
# 2              16  48.830449  2.353199
# 3               4  48.830449  2.353199
# 4               8  48.830449  2.353199

# %%
len(velo.columns)
# Out:
# 10

# %%
velo.to_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Compteurs\Cleaned\Comptage_2019_clean.csv')

# %%
print(velo['compteur_name'].nunique())
print(velo['compteur_id'].nunique())
print(velo['site_compteur_id'].nunique())
# Out:
# 81
# 81
# 60

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
velo_TS=velo[['date_comptage', 'comptage_horaire']].groupby(by='date_comptage').sum()
velo_TS
# Out:
#                comptage_horaire
# date_comptage
# 2019-01-01                16494
# 2019-01-02                29655
# 2019-01-03                34463
# 2019-01-04                34933
# 2019-01-05                26668
# ...                         ...
# 2019-12-27                88304
# 2019-12-28                74996
# 2019-12-29                68896
# 2019-12-30               105075
# 2019-12-31                  395
#
# [365 rows x 1 columns]

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(velo_TS, x=velo_TS.index, y=velo_TS.comptage_horaire, title='Comptage journalier 2019')

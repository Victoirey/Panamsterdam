# %%
import pandas as pd
import numpy as np

# %%
velo=pd.read_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Compteurs\2018_comptage-velo-donnees-compteurs.csv', sep=";")
velo.head()
# Out:
#   Identifiant du compteur           Nom du compteur  \
# 0     100047547-104047547  6 rue Julia Bartet NE-SO
# 1     100047547-104047547  6 rue Julia Bartet NE-SO
# 2     100047547-104047547  6 rue Julia Bartet NE-SO
# 3     100047547-104047547  6 rue Julia Bartet NE-SO
# 4     100047547-104047547  6 rue Julia Bartet NE-SO
#
#    Identifiant du site de comptage Nom du site de comptage  Comptage horaire  \
# 0                        100047547      6 rue Julia Bartet                 4
# 1                        100047547      6 rue Julia Bartet                30
# 2                        100047547      6 rue Julia Bartet               116
# 3                        100047547      6 rue Julia Bartet                 0
# 4                        100047547      6 rue Julia Bartet                18
#
#    Date et heure de comptage Date d'installation du site de comptage  \
# 0  2018-11-29T01:00:00+01:00                              2018-11-28
# 1  2018-11-29T22:00:00+01:00                              2018-11-28
# 2  2018-11-30T17:00:00+01:00                              2018-11-28
# 3  2018-12-03T01:00:00+01:00                              2018-11-28
# 4  2018-12-03T11:00:00+01:00                              2018-11-28
#
#                  Lien vers photo du site de comptage Coordonnées géographiques
# 0  https://www.eco-visio.net/Photos/100047547/154...         48.82648,2.303149
# 1  https://www.eco-visio.net/Photos/100047547/154...         48.82648,2.303149
# 2  https://www.eco-visio.net/Photos/100047547/154...         48.82648,2.303149
# 3  https://www.eco-visio.net/Photos/100047547/154...         48.82648,2.303149
# 4  https://www.eco-visio.net/Photos/100047547/154...         48.82648,2.303149

# %%
velo.columns
# Out:
# Index(['Identifiant du compteur', 'Nom du compteur',
#        'Identifiant du site de comptage', 'Nom du site de comptage',
#        'Comptage horaire', 'Date et heure de comptage',
#        'Date d'installation du site de comptage',
#        'Lien vers photo du site de comptage', 'Coordonnées géographiques'],
#       dtype='object')

# %%
velo.rename(columns={'Identifiant du compteur': 'compteur_id', 'Nom du compteur': 'compteur_name',
       'Identifiant du site de comptage': 'site_compteur_id', 'Nom du site de comptage': 'compteur_name2',
       'Comptage horaire': 'comptage_horaire', 'Date et heure de comptage': 'date_heure_comptage',
       "Date d'installation du site de comptage": 'date_instal',
       'Coordonnées géographiques': 'coord_gps'}, inplace=True)

# %%
velo.drop(['Lien vers photo du site de comptage'], axis=1, inplace=True)
velo
# Out:
#                 compteur_id                   compteur_name  site_compteur_id  \
# 0       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 1       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 2       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 3       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 4       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# ...                     ...                             ...               ...
# 157820  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157821  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157822  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157823  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157824  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
#
#                   compteur_name2  comptage_horaire        date_heure_comptage  \
# 0             6 rue Julia Bartet                 4  2018-11-29T01:00:00+01:00
# 1             6 rue Julia Bartet                30  2018-11-29T22:00:00+01:00
# 2             6 rue Julia Bartet               116  2018-11-30T17:00:00+01:00
# 3             6 rue Julia Bartet                 0  2018-12-03T01:00:00+01:00
# 4             6 rue Julia Bartet                18  2018-12-03T11:00:00+01:00
# ...                          ...               ...                        ...
# 157820  Pont du Garigliano SE-NO                 2  2018-12-25T01:00:00+01:00
# 157821  Pont du Garigliano SE-NO                13  2018-12-25T14:00:00+01:00
# 157822  Pont du Garigliano SE-NO                 1  2018-12-28T01:00:00+01:00
# 157823  Pont du Garigliano SE-NO                 1  2018-12-29T02:00:00+01:00
# 157824  Pont du Garigliano SE-NO                10  2018-12-30T15:00:00+01:00
#
#        date_instal           coord_gps
# 0       2018-11-28   48.82648,2.303149
# 1       2018-11-28   48.82648,2.303149
# 2       2018-11-28   48.82648,2.303149
# 3       2018-11-28   48.82648,2.303149
# 4       2018-11-28   48.82648,2.303149
# ...            ...                 ...
# 157820  2018-12-06  48.839883,2.267099
# 157821  2018-12-06  48.839883,2.267099
# 157822  2018-12-06  48.839883,2.267099
# 157823  2018-12-06  48.839883,2.267099
# 157824  2018-12-06  48.839883,2.267099
#
# [157825 rows x 8 columns]

# %%
velo.dtypes
# Out:
# compteur_id            object
# compteur_name          object
# site_compteur_id        int64
# compteur_name2         object
# comptage_horaire        int64
# date_heure_comptage    object
# date_instal            object
# coord_gps              object
# dtype: object

# %%
velo.isna().sum()
# Out:
# compteur_id            0
# compteur_name          0
# site_compteur_id       0
# compteur_name2         0
# comptage_horaire       0
# date_heure_comptage    0
# date_instal            0
# coord_gps              0
# dtype: int64

# %%
from datetime import datetime
velo['jour_comptage']=pd.to_datetime(velo['date_heure_comptage'], format='%Y/%m/%d')

# %%
velo['jour_comptage'].value_counts()
# Out:
# 2018-12-25 16:00:00+01:00    45
# 2018-12-17 10:00:00+01:00    45
# 2018-12-24 21:00:00+01:00    45
# 2018-12-23 15:00:00+01:00    45
# 2018-12-22 18:00:00+01:00    45
#                              ..
# 2018-06-20 15:00:00+02:00    14
# 2018-06-21 10:00:00+02:00    14
# 2018-06-21 14:00:00+02:00    14
# 2018-06-21 23:00:00+02:00    14
# 2018-04-21 15:00:00+02:00    14
# Name: jour_comptage, Length: 8736, dtype: int64

# %%
velo['date_comptage'] = velo['date_heure_comptage'].str[:10]
velo.head()
# Out:
#            compteur_id             compteur_name  site_compteur_id  \
# 0  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 1  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 2  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 3  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 4  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
#
#        compteur_name2  comptage_horaire        date_heure_comptage  \
# 0  6 rue Julia Bartet                 4  2018-11-29T01:00:00+01:00
# 1  6 rue Julia Bartet                30  2018-11-29T22:00:00+01:00
# 2  6 rue Julia Bartet               116  2018-11-30T17:00:00+01:00
# 3  6 rue Julia Bartet                 0  2018-12-03T01:00:00+01:00
# 4  6 rue Julia Bartet                18  2018-12-03T11:00:00+01:00
#
#   date_instal          coord_gps jour_comptage date_comptage
# 0  2018-11-28  48.82648,2.303149    2018-11-29    2018-11-29
# 1  2018-11-28  48.82648,2.303149    2018-11-29    2018-11-29
# 2  2018-11-28  48.82648,2.303149    2018-11-30    2018-11-30
# 3  2018-11-28  48.82648,2.303149    2018-12-03    2018-12-03
# 4  2018-11-28  48.82648,2.303149    2018-12-03    2018-12-03

# %%
velo['date_comptage']=pd.to_datetime(velo['date_comptage'], format='%Y/%m/%d')
velo.dtypes
# Out:
# compteur_id                    object
# compteur_name                  object
# site_compteur_id                int64
# compteur_name2                 object
# comptage_horaire                int64
# date_heure_comptage            object
# date_instal                    object
# coord_gps                      object
# jour_comptage                  object
# date_comptage          datetime64[ns]
# dtype: object

# %%
velo['heure_comptage'] = velo['date_heure_comptage'].str[11:]

# %%
velo['heure_comptage']=velo['heure_comptage'].str[:2]
velo.head()
# Out:
#            compteur_id             compteur_name  site_compteur_id  \
# 0  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 1  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 2  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 3  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 4  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
#
#        compteur_name2  comptage_horaire        date_heure_comptage  \
# 0  6 rue Julia Bartet                 4  2018-11-29T01:00:00+01:00
# 1  6 rue Julia Bartet                30  2018-11-29T22:00:00+01:00
# 2  6 rue Julia Bartet               116  2018-11-30T17:00:00+01:00
# 3  6 rue Julia Bartet                 0  2018-12-03T01:00:00+01:00
# 4  6 rue Julia Bartet                18  2018-12-03T11:00:00+01:00
#
#   date_instal          coord_gps jour_comptage date_comptage heure_comptage
# 0  2018-11-28  48.82648,2.303149    2018-11-29    2018-11-29             01
# 1  2018-11-28  48.82648,2.303149    2018-11-29    2018-11-29             22
# 2  2018-11-28  48.82648,2.303149    2018-11-30    2018-11-30             17
# 3  2018-11-28  48.82648,2.303149    2018-12-03    2018-12-03             01
# 4  2018-11-28  48.82648,2.303149    2018-12-03    2018-12-03             11

# %%
velo['heure_comptage']=velo['heure_comptage'].astype(int)
velo.dtypes
# Out:
# compteur_id                    object
# compteur_name                  object
# site_compteur_id                int64
# compteur_name2                 object
# comptage_horaire                int64
# date_heure_comptage            object
# date_instal                    object
# coord_gps                      object
# jour_comptage                  object
# date_comptage          datetime64[ns]
# heure_comptage                  int32
# dtype: object

# %%
velo[['latitude', 'longitude']] = velo['coord_gps'].str.split(',', expand=True)
velo
# Out:
#                 compteur_id                   compteur_name  site_compteur_id  \
# 0       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 1       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 2       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 3       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# 4       100047547-104047547        6 rue Julia Bartet NE-SO         100047547
# ...                     ...                             ...               ...
# 157820  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157821  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157822  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157823  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
# 157824  100047551-102047551  Pont du Garigliano SE-NO SE-NO         100047551
#
#                   compteur_name2  comptage_horaire        date_heure_comptage  \
# 0             6 rue Julia Bartet                 4  2018-11-29T01:00:00+01:00
# 1             6 rue Julia Bartet                30  2018-11-29T22:00:00+01:00
# 2             6 rue Julia Bartet               116  2018-11-30T17:00:00+01:00
# 3             6 rue Julia Bartet                 0  2018-12-03T01:00:00+01:00
# 4             6 rue Julia Bartet                18  2018-12-03T11:00:00+01:00
# ...                          ...               ...                        ...
# 157820  Pont du Garigliano SE-NO                 2  2018-12-25T01:00:00+01:00
# 157821  Pont du Garigliano SE-NO                13  2018-12-25T14:00:00+01:00
# 157822  Pont du Garigliano SE-NO                 1  2018-12-28T01:00:00+01:00
# 157823  Pont du Garigliano SE-NO                 1  2018-12-29T02:00:00+01:00
# 157824  Pont du Garigliano SE-NO                10  2018-12-30T15:00:00+01:00
#
#        date_instal           coord_gps jour_comptage date_comptage  \
# 0       2018-11-28   48.82648,2.303149    2018-11-29    2018-11-29
# 1       2018-11-28   48.82648,2.303149    2018-11-29    2018-11-29
# 2       2018-11-28   48.82648,2.303149    2018-11-30    2018-11-30
# 3       2018-11-28   48.82648,2.303149    2018-12-03    2018-12-03
# 4       2018-11-28   48.82648,2.303149    2018-12-03    2018-12-03
# ...            ...                 ...           ...           ...
# 157820  2018-12-06  48.839883,2.267099    2018-12-25    2018-12-25
# 157821  2018-12-06  48.839883,2.267099    2018-12-25    2018-12-25
# 157822  2018-12-06  48.839883,2.267099    2018-12-28    2018-12-28
# 157823  2018-12-06  48.839883,2.267099    2018-12-29    2018-12-29
# 157824  2018-12-06  48.839883,2.267099    2018-12-30    2018-12-30
#
#         heure_comptage   latitude longitude
# 0                    1   48.82648  2.303149
# 1                   22   48.82648  2.303149
# 2                   17   48.82648  2.303149
# 3                    1   48.82648  2.303149
# 4                   11   48.82648  2.303149
# ...                ...        ...       ...
# 157820               1  48.839883  2.267099
# 157821              14  48.839883  2.267099
# 157822               1  48.839883  2.267099
# 157823               2  48.839883  2.267099
# 157824              15  48.839883  2.267099
#
# [157825 rows x 13 columns]

# %%
velo.drop(['compteur_name2'], axis=1, inplace=True)

# %%
velo.drop(['jour_comptage', 'coord_gps'], axis=1, inplace=True)
velo.head()
# Out:
#            compteur_id             compteur_name  site_compteur_id  \
# 0  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 1  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 2  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 3  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
# 4  100047547-104047547  6 rue Julia Bartet NE-SO         100047547
#
#    comptage_horaire        date_heure_comptage date_instal date_comptage  \
# 0                 4  2018-11-29T01:00:00+01:00  2018-11-28    2018-11-29
# 1                30  2018-11-29T22:00:00+01:00  2018-11-28    2018-11-29
# 2               116  2018-11-30T17:00:00+01:00  2018-11-28    2018-11-30
# 3                 0  2018-12-03T01:00:00+01:00  2018-11-28    2018-12-03
# 4                18  2018-12-03T11:00:00+01:00  2018-11-28    2018-12-03
#
#    heure_comptage  latitude longitude
# 0               1  48.82648  2.303149
# 1              22  48.82648  2.303149
# 2              17  48.82648  2.303149
# 3               1  48.82648  2.303149
# 4              11  48.82648  2.303149

# %%
len(velo.columns)
# Out:
# 10

# %%
velo.to_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Compteurs\Cleaned\Comptage_2018_clean.csv')

# %%
print(velo['compteur_name'].nunique())
print(velo['compteur_id'].nunique())
print(velo['site_compteur_id'].nunique())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
velo_TS=velo[['date_comptage', 'comptage_horaire']].groupby(by='date_comptage').sum()
velo_TS
# Out:
#                comptage_horaire
# date_comptage
# 2018-01-01                 1332
# 2018-01-02                 4036
# 2018-01-03                 3716
# 2018-01-04                 3907
# 2018-01-05                 5396
# ...                         ...
# 2018-12-27                21242
# 2018-12-28                21019
# 2018-12-29                18943
# 2018-12-30                23702
# 2018-12-31                  178
#
# [365 rows x 1 columns]

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(velo_TS, x=velo_TS.index, y=velo_TS.comptage_horaire, title='Comptage journalier 2018')

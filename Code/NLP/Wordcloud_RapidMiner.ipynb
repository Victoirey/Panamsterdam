# %% [markdown]
# TO DO/PENDING
# - Elargir la liste des stopwords de RapidMiner
# - Modifier la lemmatization faite sur excel
# - Voir les ngrams
# - Sentiment analysis

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd
import  numpy as np
from PIL import Image
import requests

# %%
nonbinary = pd.read_excel(r'C:/Users/olivi/Documents/Ironhack/IRONLABS_OM/Bike mobility in Paris/Barometre villes cyclables/2021/Commentaires/wordcloud non binary only v2.xlsx', sheet_name='Filtered')
nonbinary_token=all[['Lame4', 'Count']]
nonbinary_token.head()
# Out:
#     Lame4  Count
# 0  danger    246
# 1  manque    115
# 2  nombre    107
# 3    voie    107
# 4    axes    105

# %%
nonbinary_list=[]
for i in range(0,len(nonbinary_token["Lame4"])):
    for j in range (0,nonbinary_token["Count"][i]):
        nonbinary_list.append(nonbinary_token["Lame4"][i])
nonbinary_list
pd.Series(nonbinary_list).value_counts()
str_nonbinary=' '.join(nonbinary_list)
str_nonbinary
wordcloud_all = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, collocations=False).generate(str_nonbinary)

# %%
pic = np.array(Image.open(requests.get('https://previews.123rf.com/images/vitek5g/vitek5g1804/vitek5g180400002/99281508-noir-ic%C3%B4ne-de-cycliste-isol%C3%A9-sur-fond-blanc.jpg?fj=1',stream=True).raw))
wordcloud_nonbinary = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, mask = pic, collocations=False).generate(str_nonbinary)

# %%
plt.figure(figsize = (30, 20), facecolor = 'black', edgecolor='blue') 
plt.imshow(wordcloud_nonbinary) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
female=pd.read_excel(r'C:/Users/olivi/Documents/Ironhack/IRONLABS_OM/Bike mobility in Paris/Barometre villes cyclables/2021/Commentaires/wordcloud female only v2.xlsx', sheet_name='Filtered')

# %%
female.head()
# Out:
#   Gender        Token       Lame1      Lame2      Lame3      Lame4  Count
# 0      F      usagers      usager      usage      usage      usage     97
# 1      F         feux        feux       feux       feux       feux     95
# 2      F     cyclable    cyclable   cyclable   cyclable   cyclable     94
# 3      F    motorisés  motorisées  motorisée   motorisé   motorisé     89
# 4      F  circulation   circulant  circulant  circulant  circulant     88

# %%
female_token=female[['Lame4', 'Count']]
female_token.head()
# Out:
#        Lame4  Count
# 0      usage     97
# 1       feux     95
# 2   cyclable     94
# 3   motorisé     89
# 4  circulant     88

# %%
female_list=[]
for i in range(0,len(female_token["Lame4"])):
    for j in range (0,female_token["Count"][i]):
        female_list.append(female_token["Lame4"][i])
female_list
# Out:
# ['usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
#  'usage',
# ...

# %%
pd.Series(female_list).value_counts()
# Out:
# respect       183
# usage         157
# circulant     123
# dangereuse    117
# motorisé      115
#              ...
# donner          4
# dernier         4
# dense           4
# délimitées      4
# voler           4
# Length: 604, dtype: int64

# %%
str_female=' '.join(female_list)
str_female
# Out:
# 'usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage usage feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux feux 
# ...

# %%
pic = np.array(Image.open(requests.get('https://previews.123rf.com/images/vitek5g/vitek5g1804/vitek5g180400002/99281508-noir-ic%C3%B4ne-de-cycliste-isol%C3%A9-sur-fond-blanc.jpg?fj=1',stream=True).raw))
wordcloud_female = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, mask = pic, collocations=False).generate(str_female)

# %%
plt.figure(figsize = (30, 25), facecolor = 'black', edgecolor='blue') 
plt.imshow(wordcloud_female) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
male=pd.read_excel(r'C:/Users/olivi/Documents/Ironhack/IRONLABS_OM/Bike mobility in Paris/Barometre villes cyclables/2021/Commentaires/wordcloud male only v2.xlsx', sheet_name='Filtered')

# %%
male_token=male[['Lame4', 'Count']]
male_token.head()
# Out:
#       Lame4  Count
# 0       bus     65
# 1   respect     63
# 2  cycliste     62
# 3   exemple     62
# 4      axes     58

# %%
male_list=[]
for i in range(0,len(male_token["Lame4"])):
    for j in range (0,male_token["Count"][i]):
        male_list.append(male_token["Lame4"][i])
male_list
# Out:
# ['bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'bus',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
#  'respect',
# ...

# %%
pd.Series(male_list).value_counts()
# Out:
# respect        109
# carrefour       74
# prioritaire     71
# aménagement     69
# trottoir        68
#               ...
# élevé            3
# élus             3
# encontre         3
# encourager       3
# yeux             3
# Length: 973, dtype: int64

# %%
str_male=' '.join(male_list)
str_male
# Out:
# 'bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus bus respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect respect cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste cycliste
# ...

# %%
pic = np.array(Image.open(requests.get('https://previews.123rf.com/images/vitek5g/vitek5g1804/vitek5g180400002/99281508-noir-ic%C3%B4ne-de-cycliste-isol%C3%A9-sur-fond-blanc.jpg?fj=1',stream=True).raw))
wordcloud_male = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, mask=pic, collocations=False).generate(str_male)

# %%
plt.figure(figsize = (30, 20), facecolor = 'black', edgecolor='blue') 
plt.imshow(wordcloud_male) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
fig, (ax1, ax2, ax3) =plt.subplots(3, 1, figsize=(40,40))
ax1.imshow(wordcloud_nonbinary)
ax1.set_title('Non binary')
ax2.imshow(wordcloud_female)
ax2.set_title('Female')
ax3.imshow(wordcloud_male)
ax3.set_title('Male')
plt.show()

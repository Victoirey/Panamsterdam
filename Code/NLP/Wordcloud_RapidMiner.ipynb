# %% [markdown]
# TO DO/PENDING
# - Elargir la liste des stopwords de RapidMiner
# - Modifier la lemmatization faite sur excel
# - Voir les ngrams
# - Sentiment analysis

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd
import  numpy as np
from PIL import Image
import requests

# %%
gender=pd.read_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Quali\wordcloud all genders.csv', sep=";", encoding='latin-1')

# %%
gender.head()
# Out:
#   Gender        Token        Lame1        Lame2        Lame3        Lame4  \
# 0    All    abandonné    abandonné    abandonné    abandonné    abandonné
# 1    All  aberrations  aberrations  aberrations  aberrations  aberrations
# 2    All        abord        abord        abord        abord        abord
# 3    All       abords        abord        abord        abord        abord
# 4    All      absence      absence      absence      absence      absence
#
#    Count
# 0      5
# 1      5
# 2      5
# 3      7
# 4     28

# %%
gender_token=gender[['Lame4', 'Count']]
gender_token.head()
# Out:
#          Lame4  Count
# 0    abandonné      5
# 1  aberrations      5
# 2        abord      5
# 3        abord      7
# 4      absence     28

# %%
gender_list=[]
for i in range(0,len(gender_token["Lame4"])):
    for j in range (0,gender_token["Count"][i]):
        gender_list.append(gender_token["Lame4"][i])
gender_list
# Out:
# ['abandonné',
#  'abandonné',
#  'abandonné',
#  'abandonné',
#  'abandonné',
#  'aberrations',
#  'aberrations',
#  'aberrations',
#  'aberrations',
#  'aberrations',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
# ...

# %%
pd.Series(gender_list).value_counts()
# Out:
# danger         265
# trottinette    254
# aménagé        156
# point          140
# respectant     137
#               ...
# aberrations      5
# ma              5
# lutter           5
# lui              5
# abandonné        5
# Length: 972, dtype: int64

# %%
str_gender=' '.join(gender_list)
str_gender
# Out:
# 'abandonné abandonné abandonné abandonné abandonné aberrations aberrations aberrations aberrations aberrations abord abord abord abord abord abord abord abord abord abord abord abord absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absence absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument accès accès accès accès accès accès accès accessible accessible accessible accessible accessible accessible accessible accessible accessible accessible accident accident accident accident accident accident accident accident accident accident accident accident accident acc
# ...

# %%
wordcloud_gender = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, collocations=False).generate(str_gender)

# %%
plt.figure(figsize = (10, 10), facecolor = 'black', edgecolor='blue') 
plt.imshow(wordcloud_gender) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
male=pd.read_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Quali\wordcloud male only.csv', sep=";", encoding='latin-1')

# %%
male_token=male[['Lame4', 'Count']]
male_token.head()
# Out:
#         Lame4  Count
# 0  aberration      4
# 1       abord      4
# 2     absence      6
# 3  absolument     14
# 4  accessible      4

# %%
male_list=[]
for i in range(0,len(male_token["Lame4"])):
    for j in range (0,male_token["Count"][i]):
        male_list.append(male_token["Lame4"][i])
male_list
# Out:
# ['aberration',
#  'aberration',
#  'aberration',
#  'aberration',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'accessible',
#  'accessible',
#  'accessible',
#  'accessible',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'actuellement',
#  'actuellement',
#  'actuellement',
#  'actuellement',
#  'adapté',
#  'adapté',
#  'adapté',
#  'adapté',
# ...

# %%
pd.Series(male_list).value_counts()
# Out:
# respect          183
# usage            157
# trottinette      137
# entre            128
# circulant        123
#                 ...
# lutilisation      4
# lieu               4
# lieux              4
# rochereau          4
# aberration         4
# Length: 698, dtype: int64

# %%
str_male=' '.join(male_list)
str_male
# Out:
# 'aberration aberration aberration aberration abord abord abord abord absence absence absence absence absence absence absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument accessible accessible accessible accessible accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident actuellement actuellement actuellement actuellement adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté afin afin afin afin afin afin afin afin afin afin afin afin afin afin agit agit agit agit agrandir agrandir agrandir agrandir agréable agréable agréable agréable agréable agréable agréable agréable agressifs agressifs agressifs agres
# ...

# %%
wordcloud_male = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, collocations=False).generate(str_male)

# %%
plt.figure(figsize = (10, 10), facecolor = 'black', edgecolor='blue') 
plt.imshow(wordcloud_male) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
male=pd.read_csv(r'C:\Users\Administrateur\Ironhack\LAB\DAFT_212\Final_project\Quali\wordcloud female only.csv', sep=";", encoding='latin-1')

# %%
female_token=male[['Lame4', 'Count']]
female_token.head()
# Out:
#         Lame4  Count
# 0  aberration      4
# 1       abord      4
# 2     absence      6
# 3  absolument     14
# 4  accessible      4

# %%
female_list=[]
for i in range(0,len(female_token["Lame4"])):
    for j in range (0,female_token["Count"][i]):
        female_list.append(female_token["Lame4"][i])
female_list
# Out:
# ['aberration',
#  'aberration',
#  'aberration',
#  'aberration',
#  'abord',
#  'abord',
#  'abord',
#  'abord',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absence',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'absolument',
#  'accessible',
#  'accessible',
#  'accessible',
#  'accessible',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'accident',
#  'actuellement',
#  'actuellement',
#  'actuellement',
#  'actuellement',
#  'adapté',
#  'adapté',
#  'adapté',
#  'adapté',
# ...

# %%
pd.Series(female_list).value_counts()
# Out:
# respect          183
# usage            157
# trottinette      137
# entre            128
# circulant        123
#                 ...
# lutilisation      4
# lieu               4
# lieux              4
# rochereau          4
# aberration         4
# Length: 698, dtype: int64

# %%
str_female=' '.join(female_list)
str_female
# Out:
# 'aberration aberration aberration aberration abord abord abord abord absence absence absence absence absence absence absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument absolument accessible accessible accessible accessible accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident accident actuellement actuellement actuellement actuellement adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté adapté afin afin afin afin afin afin afin afin afin afin afin afin afin afin agit agit agit agit agrandir agrandir agrandir agrandir agréable agréable agréable agréable agréable agréable agréable agréable agressifs agressifs agressifs agres
# ...

# %%
wordcloud_female = WordCloud(width = 500, height = 500, 
                background_color ='white', 
                min_font_size = 10, collocations=False).generate(str_female)

# %%
plt.figure(figsize = (10, 10), facecolor = 'black', edgecolor='blue') 
plt.imshow(wordcloud_female) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
fig, (ax1, ax2, ax3) =plt.subplots(1, 3, figsize=(20,20))
ax1.imshow(wordcloud_gender)
ax1.set_title('All genders')
ax2.imshow(wordcloud_female)
ax2.set_title('Female')
ax3.imshow(wordcloud_male)
ax3.set_title('Male')
plt.show()
